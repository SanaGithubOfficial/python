# %% [markdown]
# # Lists in Python
# * __Lists are ordered.__
# * __Lists can contains any arbitrary objects.__
# * __List elements can be accessed by an index.__
# * __Lists can be nested to arbitrary depth.__
# * __Lists are mutable__
# * __Lists are dynamic__

# %%
#empty list
x=[]
print(x)
print(type(x))
# Out:
# []
# <class 'list'>

# %%
x = ["python",10,1,315,True,False]
x
# Out:
# ['python', 10, 1, 315, True, False]

# %%
print(type(x))
# Out:
# <class 'list'>

# %%
#indexing of list
print(x[0])
print(type(x[0]))
print(x[1])
print(type(x[1]))
print(x[2])
print(type(x[2]))
print(x[3])
print(type(x[3]))
print(x[4])
print(type(x[4]))
print(x[5])
print(type(x[5]))
# Out:
# python
# <class 'str'>
# 10
# <class 'int'>
# 1
# <class 'int'>
# 315
# <class 'int'>
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
print(x[-1])
print(type(x[-1]))
print(x[-2])
print(type(x[-2]))
print(x[-3])
print(type(x[-3]))
print(x[-4])
print(type(x[-4]))
print(x[-5])
print(type(x[-5]))
print(x[-6])
print(type(x[-6]))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>
# 315
# <class 'int'>
# 1
# <class 'int'>
# 10
# <class 'int'>
# python
# <class 'str'>

# %%
#slicing of list
list1=['Hello world',3.147,100,True,False,['Python',15,3.147],("Hello Pune",3.147),{10,10,20},{'a':'apple'}]
list1
# Out:
# ['Hello world',
#  3.147,
#  100,
#  True,
#  False,
#  ['Python', 15, 3.147],
#  ('Hello Pune', 3.147),
#  {10, 20},
#  {'a': 'apple'}]

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list1[0]
# Out:
# 'Hello world'

# %%
print(list1)
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], ('Hello Pune', 3.147), {10, 20}, {'a': 'apple'}]

# %%
x= list1[5]
print(type(x))
# Out:
# <class 'list'>

# %%
x= list1[6]
print(type(x))
# Out:
# <class 'tuple'>

# %%
x= list1[7]
print(type(x))
# Out:
# <class 'set'>

# %%
x= list1[8]
print(type(x))
# Out:
# <class 'dict'>

# %%
print(list1)
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], ('Hello Pune', 3.147), {10, 20}, {'a': 'apple'}]

# %%
x1=list1[5]
print(x1)
# Out:
# ['Python', 15, 3.147]

# %%
print(list1[5][0])
# Out:
# Python

# %%
list1=['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147],[['ganesh',[['komal']],['rohit',['kartik']]]],('Hello Pune', 3.147,(('Sana',("shahid")))), {10,10, 20}, {'a': 'apple'}]
print(list1)
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], [['ganesh', [['komal']], ['rohit', ['kartik']]]], ('Hello Pune', 3.147, ('Sana', 'shahid')), {10, 20}, {'a': 'apple'}]

# %%
list1[5][0]
# Out:
# 'Python'

# %%
list1[6][0][0]
# Out:
# 'ganesh'

# %%
list1[6][0][1][0][0]
# Out:
# 'komal'

# %%
list1[6][0][2][0]
# Out:
# 'rohit'

# %%
list1[6][0][2][1][0]
# Out:
# 'kartik'

# %%
print(list1)
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], [['ganesh', [['komal']], ['rohit', ['kartik']]]], ('Hello Pune', 3.147, ('Sana', 'shahid')), {10, 20}, {'a': 'apple'}]

# %%
list1[7][0]
# Out:
# 'Hello Pune'

# %%
list1[7][2][0]
# Out:
# 'Sana'

# %%
list1[7][2][1]
# Out:
# 'shahid'

# %%
list1
# Out:
# ['Hello world',
#  3.147,
#  100,
#  True,
#  False,
#  ['Python', 15, 3.147],
#  [['ganesh', [['komal']], ['rohit', ['kartik']]]],
#  ('Hello Pune', 3.147, ('Sana', 'shahid')),
#  {10, 20},
#  {'a': 'apple'}]

# %%
list1=['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147],[['ganesh',[['komal']],['rohit',['kartik']]]],('Hello Pune', 3.147,(('Sana',("shahid")))), {10,10, 20}, {'a': 'apple'}]
print(list1)

list1[6]
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], [['ganesh', [['komal']], ['rohit', ['kartik']]]], ('Hello Pune', 3.147, ('Sana', 'shahid')), {10, 20}, {'a': 'apple'}]
# [['ganesh', [['komal']], ['rohit', ['kartik']]]]

# %%
list1[6][0]
# Out:
# ['ganesh', [['komal']], ['rohit', ['kartik']]]

# %%
list1[6][0][2]
# Out:
# ['rohit', ['kartik']]

# %%
list1[6][0][2][1]
# Out:
# ['kartik']

# %%
list1[6][0][2][1][0]
# Out:
# 'kartik'

# %%
#slicing of list
list1=['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147],[['ganesh',[['komal']],['rohit',['kartik']]]],('Hello Pune', 3.147,(('Sana',("shahid")))), {10,10, 20}, {'a': 'apple'}]
print(list1)
# Out:
# ['Hello world', 3.147, 100, True, False, ['Python', 15, 3.147], [['ganesh', [['komal']], ['rohit', ['kartik']]]], ('Hello Pune', 3.147, ('Sana', 'shahid')), {10, 20}, {'a': 'apple'}]

# %%
list1[5][:3]
# Out:
# ['Python', 15, 3.147]

# %%
list1[6][0][::]
# Out:
# ['ganesh', [['komal']], ['rohit', ['kartik']]]

# %%
list1[6][0][:0]
# Out:
# []

# %%
list1[6][0][:1]
# Out:
# ['ganesh']

# %%
list1[6][0][:2]
# Out:
# ['ganesh', [['komal']]]

# %%
list1[6][0][:3]
# Out:
# ['ganesh', [['komal']], ['rohit', ['kartik']]]

# %%
list1[6][0][0:]
# Out:
# ['ganesh', [['komal']], ['rohit', ['kartik']]]

# %%
list1[6][0][1:]
# Out:
# [[['komal']], ['rohit', ['kartik']]]

# %%
list1[6][0][2:]
# Out:
# [['rohit', ['kartik']]]

# %%
list1[6][0][3:]
# Out:
# []

# %%
list1[5]
# Out:
# ['Python', 15, 3.147]

# %%
list1[5][0][::2]
# Out:
# 'Pto'

# %%
list1[6][0][2][1][0]
# Out:
# 'kartik'

# %%
list1[6][0][2][1][0][1:7:4]
# Out:
# 'ak'

# %%
print(list1[6][0][2][1][0][1])
print(list1[6][0][2][1][0][5])
# Out:
# a
# k

# %%
# List Opeartions

# CRUD
# How to add any data inside the list
# Append, Extend, Insert

# Append: it appends data one by one.
# extend: It Extends data inside list.
# Insert: It takes two parameter at one time, first parameter is your index[position] value and second parameter is your data.

# %%
list1=["hello world"]
list1
# Out:
# ['hello world']

# %%
#append in list
list1.append("sameer")
list1
# Out:
# ['hello world', 'sameer']

# %%
list1.pop()
print(list1)
# Out:
# ['hello world']

# %%
list1.pop()
list1
# Out:
# []

# %%
list1.append('sana')
list1
# Out:
# ['sana']

# %%
list1.append(10)
list1
# Out:
# ['sana', 10]

# %%
#extend in list
list1.extend(['sana'])

# %%
list1
# Out:
# ['sana', 10, 'sana']

# %%
list1.pop()
# Out:
# 'sana'

# %%
list1.append([10,20])

# %%
list1
# Out:
# ['sana', 10, [10, 20]]

# %%
list1.extend([10,20])
list1
# Out:
# ['sana', 10, [10, 20], 10, 20]

# %%
#insert in list
list1.insert(0,'ganesh')
list1
# Out:
# ['ganesh', 'sana', 10, [10, 20], 10, 20]

# %%
#pop function
list1.pop()
list1
# Out:
# ['ganesh', 'sana', 10, [10, 20], 10]

# %%
list1.pop()
list1
# Out:
# ['ganesh', 'sana', 10, [10, 20]]

# %%
#delete
print(list1)
# Out:
# ['ganesh', 'sana', 10, [10, 20]]

# %%
#popitem
del(list1[0])
list1
# Out:
# ['sana', 10, [10, 20]]

# %%
#updating the list
list1
list1[2]='sana mj'
list1
# Out:
# ['sana', 10, 'sana mj']

# %%
#calculation [agreegate function]
#len(),sum(),count(),min(),max()
list2=[2,4,23,45,23232,442,2,2,4,53,34,94,]
print(list2)

#f string
print(f"total length of list:{list2}")
print(f"total Length of list:{len(list2)}")
print(f"total sum of list:{sum(list2)}")
print(f"minimum number of list:{min(list2)}")
print(f"maximum number of list:{max(list2)}")
print(f"total count of the value:{list2.count(2)}")
# Out:
# [2, 4, 23, 45, 23232, 442, 2, 2, 4, 53, 34, 94]
# total length of list:[2, 4, 23, 45, 23232, 442, 2, 2, 4, 53, 34, 94]
# total Length of list:12
# total sum of list:23937
# minimum number of list:2
# maximum number of list:23232
# total count of the value:3

# %%
#split
txt="python is a programming language"
print(type(txt))

x=txt.split()
print(x)
print(type(x))
# Out:
# <class 'str'>
# ['python', 'is', 'a', 'programming', 'language']
# <class 'list'>

# %%
x="p,y,t,h,o,n"
y=x.split()
y
# Out:
# ['p,y,t,h,o,n']

# %%
x="p,y,t,h,o,n"
y=x.split(',')
y
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
y[0]
# Out:
# 'p'

# %%
# Copy the list

# Sallow copy
# Deep copy
x=["apple","boy","doll","elephant"]
x
# Out:
# ['apple', 'boy', 'doll', 'elephant']

# %%
#deep copy
y=x
print(y)
# Out:
# ['apple', 'boy', 'doll', 'elephant']

# %%
y.append("kartik")
y
# Out:
# ['apple', 'boy', 'doll', 'elephant', 'kartik']

# %%
y.pop()
# Out:
# 'kartik'

# %%
y
# Out:
# ['apple', 'boy', 'doll', 'elephant']

# %%
x
# Out:
# ['apple', 'boy', 'doll', 'elephant']

# %%
x.append('ganesh')
x
# Out:
# ['apple', 'boy', 'doll', 'elephant', 'ganesh']

# %%
y
# Out:
# ['apple', 'boy', 'doll', 'elephant', 'ganesh']

# %%
#shallow copy
y2=['python','apple']
y2
# Out:
# ['python', 'apple']

# %%
y3=y2.copy()
y3
# Out:
# ['python', 'apple']

# %%
y2.append('sana')
y2
# Out:
# ['python', 'apple', 'sana', 'sana']

# %%
y3
# Out:
# ['python', 'apple']

# %%
y2.pop()
# Out:
# 'sana'

# %%
print(y2)
y3
# Out:
# ['python', 'apple', 'sana']
# ['python', 'apple']
