# %%
### 🧮 *Python Function Practice Questions (Set 2)*

# 1. Define a function to convert *Celsius to Fahrenheit*.
#2. Write a function to check if a number is a *perfect square*.
#3. Create a function to return the *length of a string*.
#4. Define a function to find the *sum of all digits* of a number.
#5. Write a function that accepts a string and returns it in *uppercase*.
#6. Define a function to count the number of *words in a sentence*.
#7. Write a function to return the *smallest number in a list*.
#8. Define a function that *multiplies all items in a list*.
#9. Create a function to check if a number is *Armstrong number*.
#10. Write a function that returns *True if a number is palindrome*, else False.
#11. Create a function that accepts a list and returns the *average of numbers*.
#12. Write a function that takes two strings and returns *True if they are anagrams*.
#13. Define a function that takes a list and returns the *count of even numbers*.
#14. Write a function to remove *duplicates from a list*.
#15. Create a function that returns a list of all *prime numbers in a range*.
#16. Write a function to calculate the **power without using ** operator**.
#17. Define a function that returns the *second largest element* in a list.
#18. Write a function that accepts a string and returns *number of vowels and consonants*.
#19. Create a function that accepts a number and returns a list of its *factors*.
#20. Write a function that reverses a given list *without using built-in reverse*.
#21. Define a function that accepts a dictionary and prints *keys and values*.
#22. Write a function that accepts a number and returns a list of its *multiples up to 100*.
#23. Create a function that swaps the *first and last elements* of a list.
#24. Write a function to find the *common elements between two lists*.
#25. Define a function that accepts a string and returns a *new string with vowels removed*.
#26. Write a function to *flatten a nested list* (e.g., [[1,2],[3,4]] → [1,2,3,4]).
#27. Define a function that accepts a sentence and returns the *longest word*.
#28. Create a function that accepts a string and returns *True if it’s a pangram*.
#29. Write a function to return a list of numbers that are *both even and divisible by 3*.
#30. Create a function that prints a *pattern of stars in pyramid shape* for given number of rows.

# %%
### 🧮 *Python Function Practice Questions (Set 3)*

#1. Write a function that accepts a list and returns the list in *reverse order*.
#2. Define a function that takes a number and returns *True if it’s odd*, else False.
#3. Create a function to *generate a list of squares* from 1 to n.
#4. Write a function that *returns a dictionary* of word frequencies from a sentence.
#5. Define a function to check if all elements in a list are *unique*.
#6. Create a function that returns the *sum of even-indexed elements* in a list.
#7. Write a function to extract *digits from a string* and return them as a list.
#8. Define a function that takes a number and returns the *sum of its prime divisors*.
#9. Create a function that *counts the number of uppercase and lowercase letters* in a string.
#10. Write a function that takes a list and returns *True if it's sorted*, else False.
#11. Define a function that takes a sentence and returns the *number of punctuation marks*.
#12. Write a function to return *all substrings* of a given string.
#13. Create a function that finds the *most frequent element in a list*.
#14. Define a function that returns a list of *palindrome strings* from a list of words.
#15. Write a function to check if a number is a *Harshad number* (divisible by sum of digits).
#16. Create a function that removes all *None values* from a list.
#17. Write a function to generate the *Pascal’s triangle up to n rows*.
#18. Define a function that takes a string and returns a new string with *reversed words*.
#19. Create a function that finds the *first non-repeating character* in a string.
#20. Write a function to return the *difference between max and min* of a list.

# %%
# 1. Define a function to convert *Celsius to Fahrenheit*.
def celciusFahrenheit():
    #F = (C * 9/5) + 32
    celcius=int(input("Enter celcius:"))
    f=((celcius*9/5)+32)
    return f   
celciusFahrenheit()
# Out:
# Enter celcius: 23
# 73.4

# %%
#2. Write a function to check if a number is a *perfect square*.
def numisSquare():
    num1=int(input("enter number:"))
    while True:
        square=num1**num1
        num1+=1
    print("square:",square)
numisSquare()

# %%
#3. Create a function to return the *length of a string*.
def lenstr():
    string=input("Enter a string:")
    count=0
    for i in range(len(string)):
        print(i)
obj = lenstr()
# Out:
# Enter a string: sana
# 0
# 1
# 2
# 3

# %%
#4. Define a function to find the *sum of all digits* of a number.
def sumdigit(num):
    num=abs(num)
    strNum=str(num)
    sumDigit=0
    for digit in strNum:
        sumDigit += int(digit)
    return sumDigit 
    
obj1=sumdigit(123424) 
obj1
# Out:
# 16

# %%
#help(abs)
#help(str)

# %%
#5. Write a function that accepts a string and returns it in *uppercase*.
def upperstring():
    string1=input("Enter a string:")
    string=string1.upper()
    return string
obj=upperstring()  
obj
# Out:
# Enter a string: SanA muJawAr
# 'SANA MUJAWAR'

# %%
#6. Define a function to count the number of *words in a sentence*.
def wordinsentence():
    a=input("Enter a sentence:")
    a1=a.split()
    print(a1,":",len(a1))
obj=wordinsentence()    
obj
# Out:
# Enter a sentence: python is a language that i know most in other languages
# ['python', 'is', 'a', 'language', 'that', 'i', 'know', 'most', 'in', 'other', 'languages'] : 11

# %%
#7. Write a function to return the *smallest number in a list*.
def smallistnum():
    numlist=[]
    while True:
        userNum=int(input("Enter a number"))
        if userNum == 0:
            break
        numlist.append(userNum)
        smallest=numlist[0]
        for val in numlist:
            if val<smallest:
                smallest=val
    print("List of numbers is:",numlist) 
    print("smallest number in list is:",val)
obj=smallistnum()   
obj
# Out:
# Enter a number 2
# Enter a number 4
# Enter a number 5
# Enter a number 7
# Enter a number 6
# Enter a number 5
# Enter a number 3
# Enter a number 1
# Enter a number 0
# List of numbers is: [2, 4, 5, 7, 6, 5, 3, 1]
# smallest number in list is: 1

# %%
#8. Define a function that *multiplies all items in a list*.
def mulnum():
    numlist=[]
    mul=1
    while True:
        userNum=int(input("Enter a number:"))
        if userNum == 0:
            break
        numlist.append(userNum) 
        mul=mul*userNum
    print("list of numbers is: ",numlist)  
    print("multiplies all items in a list is:",mul)
obj= mulnum()    
obj
# Out:
# Enter a number: 2
# Enter a number: 4
# Enter a number: 3
# Enter a number: 0
# list of numbers is:  [2, 4, 3]
# multiplies all items in a list is: 24

# %%
#9. Create a function to check if a number is *Armstrong number*.
def armstrongnum():
    num=int(input("Enter a number:"))
    org=num
    sum=0
    n=len(str(num))
    while num>0:
        digit=num%10
        sum += digit ** n
        num //= 10
    if sum == org:
        print(f"{org} is armstrong number.")
    else:
        print(f"{org} is not armstrong number.")
obj=armstrongnum()  
obj
# Out:
# Enter a number: 407
# 407 is armstrong number.

# %%
#10. Write a function that returns *True if a number is palindrome*, else False.
def palindrome():
    num=int(input("enter a number"))
    while True:
        for i in num :
            if i

# %%
#11. Create a function that accepts a list and returns the *average of numbers*.
