# %%
print("hello world")
# Out:
# hello world

# %%
print('Hello World')
# Out:
# Hello World

# %%
txt='On April 14, 1865, five days after the Confederate surrender at Appomattox, he was attending a play at Ford's Theatre in Washington, D.C., when he was fatally shot by Confederate sympathizer John Wilkes Booth. Lincoln is remembered as a martyr and a national hero for his wartime leadership and for his efforts to preserve the Union and abolish slavery. He is often ranked in both popular and scholarly polls as the greatest president in American history.'
print(txt)
# Out:
#   Cell In[4], line 1
#     txt='On April 14, 1865, five days after the Confederate surrender at Appomattox, he was attending a play at Ford's Theatre in Washington, D.C., when he was fatally shot by Confederate sympathizer John Wilkes Booth. Lincoln is remembered as a martyr and a national hero for his wartime leadership and for his efforts to preserve the Union and abolish slavery. He is often ranked in both popular and scholarly polls as the greatest president in American history.'
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# ...

# %%
txt="On April 14, 1865, five days after the Confederate surrender at Appomattox, he was attending a play at Ford's Theatre in Washington, D.C., when he was fatally shot by Confederate sympathizer John Wilkes Booth. Lincoln is remembered as a martyr and a national hero for his wartime leadership and for his efforts to preserve the Union and abolish slavery. He is often ranked in both popular and scholarly polls as the greatest president in American history."
print(txt)
# Out:
# On April 14, 1865, five days after the Confederate surrender at Appomattox, he was attending a play at Ford's Theatre in Washington, D.C., when he was fatally shot by Confederate sympathizer John Wilkes Booth. Lincoln is remembered as a martyr and a national hero for his wartime leadership and for his efforts to preserve the Union and abolish slavery. He is often ranked in both popular and scholarly polls as the greatest president in American history.

# %% [markdown]
# # indexing of a String

# %%
x= 'hello world'
print(x)
# Out:
# hello world

# %%
print(x[0])
print(x[1])
print(x[2])
print(x[3])
print(x[4])
print(x[5])
print(x[6])
print(x[7])
print(x[8])
print(x[9])
print(x[10])
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
print(x[-1])
print(x[-2])
print(x[-3])
print(x[-4])
print(x[-5])
print(x[-6])
print(x[-7])
print(x[-8])
print(x[-9])
print(x[-10])
print(x[-11])
# Out:
# d
# l
# r
# o
# w
#
# o
# l
# l
# e
# h

# %%
# total characters inside the string
print(len(x))  # length of string
# Out:
# 11

# %%
# slicing of string
x
# Out:
# 'Hello World'

# %%
x[0:5]  #[starts:ends] n-1= 5-1= 4
# Out:
# 'Hello'

# %%
#world
x[6:11]
# Out:
# 'World'

# %%
#striding of string
x
# Out:
# 'Hello World'

# %%
x[::]
# Out:
# 'Hello World'

# %%
x[:100000]
# Out:
# 'Hello World'

# %%
x[100:]
# Out:
# ''

# %%
x[:100]
# Out:
# 'Hello World'

# %%
x[:]
# Out:
# 'Hello World'

# %%
x[::]
# Out:
# 'Hello World'

# %%
x[::2]
# Out:
# 'HloWrd'

# %%
x
# Out:
# 'Hello World'

# %%
x[::-1]
# Out:
# 'dlroW olleH'

# %%
#concatenation
msg = "Hello Python"
msg2 = "how are you?"
statement = msg+msg2
print(statement)
# Out:
# Hello Pythonhow are you?

# %%
print(f"{msg}\n{msg2}")
# Out:
# Hello Python
# how are you?

# %%
print("Hello Python\nhow are you?") #\n for new line
# Out:
# Hello Python
# how are you?

# %%
#repeatetion of string
4*"Sana"
# Out:
# 'SanaSanaSanaSana'

# %%
4*12
# Out:
# 48

# %%
#String operations 
x1 = "hello WORLD"
print(x1)

#upper()
upper1= x1.upper()
print("After upper case:",upper1)

#lower()
lower1 = x1.lower()
print("After lower case:",lower1)

#capitalize
cap1 = x1.capitalize()
print("After capitalize:",cap1)

#title
title1 = x1.title()
print('after tittle:',title1)
# Out:
# hello WORLD
# After upper case: HELLO WORLD
# After lower case: hello world
# After capitalize: Hello world
# after tittle: Hello World

# %%
#find
x
# Out:
# 'Hello World'

# %%
x.find("W")
# Out:
# 6

# %%
x.find("o")
# Out:
# 4

# %%
x.find("h")
# Out:
# -1

# %%
x
# Out:
# 'Hello World'

# %%
print(x1.find('l'))
x1.find('lo')
# Out:
# 2
# 3

# %%
x1.find('lo')
# Out:
# 3

# %%
x1 = 'Hello World'
x1.find('lo')
# Out:
# 3

# %%
x1.find('ld')
# Out:
# 9

# %%
#replace
x="Hello World"

# %%
x
# Out:
# 'Hello World'

# %%
x.replace("World","sanu")
# Out:
# 'Hello sanu'

# %%
x.replace("Hello","hii")
# Out:
# 'hii World'

# %%
x.find('dhslf')
# Out:
# -1

# %%
#format() function
x= "hi, myself {} and i am {} years old."

# %%
txt="Lincoln was born into poverty in Kentucky and raised on the frontier. He was self-educated and became a lawyer, Illinois state legislator, and U.S. representative. Angered by the Kansas–Nebraska Act of 1854, which opened the territories to slavery, he became a leader of the new Republican Party. He reached a national audience in the 1858 Senate campaign debates against Stephen A. Douglas. Lincoln won the 1860 presidential election, but the South viewed his election as a threat to slavery, and Southern states began seceding to form the Confederate States of America. A month after Lincoln assumed the presidency, Confederate forces attacked Fort Sumter, starting the Civil War."
print(txt)
# Out:
# Lincoln was born into poverty in Kentucky and raised on the frontier. He was self-educated and became a lawyer, Illinois state legislator, and U.S. representative. Angered by the Kansas–Nebraska Act of 1854, which opened the territories to slavery, he became a leader of the new Republican Party. He reached a national audience in the 1858 Senate campaign debates against Stephen A. Douglas. Lincoln won the 1860 presidential election, but the South viewed his election as a threat to slavery, and Southern states began seceding to form the Confederate States of America. A month after Lincoln assumed the presidency, Confederate forces attacked Fort Sumter, starting the Civil War.

# %%
txt.replace("Lincoln","sana")
# Out:
# 'sana was born into poverty in Kentucky and raised on the frontier. He was self-educated and became a lawyer, Illinois state legislator, and U.S. representative. Angered by the Kansas–Nebraska Act of 1854, which opened the territories to slavery, he became a leader of the new Republican Party. He reached a national audience in the 1858 Senate campaign debates against Stephen A. Douglas. sana won the 1860 presidential election, but the South viewed his election as a threat to slavery, and Southern states began seceding to form the Confederate States of America. A month after sana assumed the presidency, Confederate forces attacked Fort Sumter, starting the Civil War.'

# %%
x= "hi, myself {} and iam {} years old."
print(x)

print(x.format("Sana",12))
print(x.format("sanu",10))
# Out:
# hi, myself {} and iam {} years old.
# hi, myself Sana and iam 12 years old.
# hi, myself sanu and iam 10 years old.

# %%
x= "hi, myself {0} and i am {1} years old."
print(x)
print(x.format(98,"Sanu"))
# Out:
# hi, myself {0} and i am {1} years old.
# hi, myself 98 and i am Sanu years old.

# %%
print(x.format("sanu",39))
# Out:
# hi, myself sanu and i am 39 years old.

# %%
x= "hi, myself {a1} and i am {a2} years old.I lived at {a3}."
print(x)

print(x.format(a1="Ganesh", a2=290 , a3="lohegav"))
# Out:
# hi, myself {a1} and i am {a2} years old.I lived at {a3}.
# hi, myself Ganesh and i am 290 years old.I lived at lohegav.

# %%
x= "       sana          "
print(x)
# Out:
#        sana

# %%
x.strip()
# Out:
# 'sana'

# %%
names="Komal, Ganesh ,Krtik, Rohit, Sahaid, Sana"
print(names)
print(type(names))
# Out:
# Komal, Ganesh ,Krtik, Rohit, Sahaid, Sana
# <class 'str'>

# %%
y= names.split()
y
# Out:
# ['Komal,', 'Ganesh', ',Krtik,', 'Rohit,', 'Sahaid,', 'Sana']

# %%
type(y)
# Out:
# list

# %%
z= names.split()
z
# Out:
# ['Komal,', 'Ganesh', ',Krtik,', 'Rohit,', 'Sahaid,', 'Sana']

# %%
x= "hello"
y= "world"
z=x+" "+y
print(z)
# Out:
# hello world

# %%
x= "Apple"
x.replace('p','*')
# Out:
# 'A**le'

# %%
name='Myself Komal and I am 12 years old.'
print(name)
name1 = name[7:12]
print(name1)

name2 = name1.upper()
print(name2)

txt = name[:7]
print(txt)

txt2 = name[12:]
print(txt2)
# Out:
# Myself Komal and I am 12 years old.
# Komal
# KOMAL
# Myself
#  and I am 12 years old.

# %%
fulltxt= txt+name2+txt2
print(fulltxt)
# Out:
# Myself KOMAL and I am 12 years old.

# %%
#1.Write a code that replaces all the occurrences of "a" with "@" in a given string."Banana"

#2. Given a string 'apple, banana, orange', split into a list of fruits

#3. Write a program to extract the first 5 characters fron the string "Python Programming"

#4. Given a string "hello world", convert it to uppercase using string method

#5.Write a python program that two strings, "Hello" and "World", and concatenates them with
# a space in between.

#6. Write a program to find the index of the first occurrence of "is" in the string 
# "This is a test"

#7. Given a string "        Python             ", remove leading and trailing whitespace.

#8. Write a function that replaces all vowels in a string with the character *.
# Hello world

#9. Write a program that uses f-sting to create a sentence like "My name is Alice and I am 25 years old.
# " from variables name= "Alice" and age =25

#10. Write a function to count how many times the letter "a" appears in the string "banana", 
# ignoring case.

# %%
#1.Write a code that replaces all the occurrences of "a" with "@" in a given string."Banana"
x="banana"
x.replace('a','@')
# Out:
# 'b@n@n@'

# %%
#2. Given a string 'apple, banana, orange', split into a list of fruits
fruits='apple, banana, orange'
print(fruits)
y=fruits.split()
y
# Out:
# apple, banana, orange
# ['apple,', 'banana,', 'orange']

# %%
#3. Write a program to extract the first 5 characters fron the string "Python Programming"
x= "Python Programming"
x[:5]
# Out:
# 'Pytho'

# %%
#4. Given a string "hello world", convert it to uppercase using string method
x="hello world"
y=x.upper()
y
# Out:
# 'HELLO WORLD'

# %%
#5.Write a python program that two strings, "Hello" and "World", and concatenates them with a space in between.
x="Hello" 
y="World"
z=x+" "+y
print(z)
# Out:
# Hello World

# %%
#6. Write a program to find the index of the first occurrence of "is" in the string "This is a test"
x="This is a test"
x.find("is")
# Out:
# 2

# %%
#7. Given a string "        Python             ", remove leading and trailing whitespace.
x="        Python             "
x.strip()
# Out:
# 'Python'

# %%
#8. Write a function that replaces all vowels in a string with the character *.
# Hello world
# Out:
# 'Hell* W*rld'

# %%
#9. Write a program that uses f-sting to create a sentence like "My name is Alice and I am 25 years old. " from variables name= "Alice" and age =25
name="Alice"
age=25

sentence=f"My name is {name} and I am {age} years old"
print(sentence)
# Out:
# My name is Alice and I am 25 years old

# %%
#10. Write a function to count how many times the letter "a" appears in the string "banana",  ignoring case.
x="banana"
y=f"count letter a in banana:{x.count('a')}"
print(y)
# Out:
# count letter a in banana:3
